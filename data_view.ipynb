# %%
import json
import numpy as np

# %%
with open("./data/train.id.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
for i, (x, y) in enumerate(data):
    print(len(x), len(y))
    if len(x) - 2 != len(y):
        print(i)
# Out:
# 5 3
# 16 14
# 5 3
# 14 12
# 5 3
# 13 11
# 5 3
# 17 15
# 23 21
# 15 13
# 18 16
# 15 13
# 16 14
# 20 18
# 30 28
# 36 34
# 10 8
# 24 22
# 14 12
# 11 9
# 20 18
# 69 67
# 47 45
# 23 21
# 32 30
# 22 20
# 16 14
# 21 19
# 15 13
# 8 6
# 67 65
# 30 28
# 16 14
# 24 22
# 14 12
# 9 7
# 16 14
# 60 58
# 10 8
# 5 3
# 12 10
# 19 17
# 15 13
# 18 16
# 27 25
# 20 18
# 14 12
# 13 11
# 11 9
# 11 9
# 13 11
# 12 10
# 10 8
# 31 29
# 17 15
# 10 8
# 7 5
# 31 29
# 25 23
# 19 17
# 14 12
# 18 16
# 14 12
# 27 25
# 8 6
# 9 7
# 26 24
# 28 26
# 20 18
# 13 11
# 11 9
# 14 12
# 25 23
# 15 13
# 14 12
# 15 13
# 14 12
# 9 7
# 23 21
# 22 20
# 17 15
# 51 49
# 35 33
# 12 10
# 10 8
# 9 7
# 11 9
# 18 16
# 29 27
# 12 10
# 22 20
# 20 18
# 12 10
# 9 7
# 17 15
# 12 10
# 11 9
# 16 14
# 11 9
# 10 8
# 17 15
# 8 6
# 8 6
# 7 5
# 16 14
# 13 11
# 8 6
# 13 11
# 7 5
# 10 8
# 14 12
# 11 9
# 19 17
# 11 9
# 15 13
# 15 13
# 32 30
# 27 25
# 21 19
# 11 9
# 24 22
# 17 15
# 7 5
# 13 11
# 13 11
# 25 23
# 21 19
# 12 10
# 17 15
# 25 23
# 14 12
# 11 9
# ...
